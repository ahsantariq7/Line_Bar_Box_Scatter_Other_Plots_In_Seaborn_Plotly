# %%
import seaborn as sns
import matplotlib.pyplot as plt 

titanic_data=sns.load_dataset("titanic")
titanic_data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.barplot(x="class",y="fare",data=titanic_data,linewidth=5,facecolor=(1,1,1,0),errcolor=".2",edgecolor=".2")
plt.title("Titanic DataSet")
plt.figure(figsize=(10,9))
sns.set_style("dark")

plt.show()

# %%
sns.barplot(x="class",y="fare",data=titanic_data,linewidth=5,facecolor=(0.2,0.4,0.7,0.9),errcolor=".5",edgecolor=".6")
plt.title("Titanic DataSet")
plt.figure(figsize=(10,9))
sns.set_style("dark")

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt 

sns.set_style(style="whitegrid")

titanic_data=sns.load_dataset("titanic")
titanic_data

sns.boxplot(x="class",y="fare",data=titanic_data)
# Out:
# <AxesSubplot:xlabel='class', ylabel='fare'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt 

sns.set_style(style="whitegrid")

tips=sns.load_dataset("tips")
print(tips)

sns.boxplot(x="size",y="total_bill",data=tips)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
# <AxesSubplot:xlabel='size', ylabel='total_bill'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt 

sns.set_style(style="whitegrid")

sns.boxplot(x="size",y="tip",data=tips)
# Out:
# <AxesSubplot:xlabel='size', ylabel='tip'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt 

sns.set_style(style="dark")

sns.boxplot(x="size",y="tip",data=tips)
# Out:
# <AxesSubplot:xlabel='size', ylabel='tip'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt 

sns.set_style(style="ticks")

sns.boxplot(x="day",y="tip",data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt 

sns.set_style(style="ticks")

sns.boxplot(x="day",y="tip",data=tips,saturation=0)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
import numpy as np
import pandas as pd
import seaborn as sns

tip=sns.load_dataset("tips")
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tip.describe(include="all")
# Out:
#         total_bill         tip   sex smoker  day    time        size
# count   244.000000  244.000000   244    244  244     244  244.000000
# unique         NaN         NaN     2      2    4       2         NaN
# top            NaN         NaN  Male     No  Sat  Dinner         NaN
# freq           NaN         NaN   157    151   87     176         NaN
# mean     19.785943    2.998279   NaN    NaN  NaN     NaN    2.569672
# std       8.902412    1.383638   NaN    NaN  NaN     NaN    0.951100
# min       3.070000    1.000000   NaN    NaN  NaN     NaN    1.000000
# 25%      13.347500    2.000000   NaN    NaN  NaN     NaN    2.000000
# 50%      17.795000    2.900000   NaN    NaN  NaN     NaN    2.000000
# 75%      24.127500    3.562500   NaN    NaN  NaN     NaN    3.000000
# max      50.810000   10.000000   NaN    NaN  NaN     NaN    6.000000

# %%
tip.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
sns.set_style(style="ticks")

sns.boxplot(x=tip["total_bill"])
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.set_style(style="ticks")

sns.boxplot(y=tip["total_bill"])
# Out:
# <AxesSubplot:ylabel='total_bill'>

# %%
sns.set_style(style="ticks")

sns.boxplot(x="tip",y="day",hue="smoker",data=tip)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='day'>

# %%
sns.set_style(style="ticks")

sns.boxplot(x="tip",y="day",hue="smoker",data=tip,palette="Set2")
# Out:
# <AxesSubplot:xlabel='tip', ylabel='day'>

# %%
sns.set_style(style="ticks")

sns.boxplot(x="tip",y="day",hue="smoker",data=tip,palette="Set2",dodge=True)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='day'>

# %%
sns.set_style(style="ticks")

sns.boxplot(x="tip",y="day",hue="smoker",data=tip,palette="Set2",dodge=False)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='day'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt 

sns.set_style(style="dark")

sns.boxplot(x="size",y="tip",data=tips,color="#83a832")
# Out:
# <AxesSubplot:xlabel='size', ylabel='tip'>

# %%
sns.set_style(style="dark")

sns.boxplot(x="size",y="tip",data=tips,orient="v")
# Out:
# <AxesSubplot:xlabel='size', ylabel='tip'>

# %%
sns.set_style(style="dark")

sns.boxplot(x="size",y="tip",data=tips,orient="h")
# Out:
# <AxesSubplot:xlabel='size', ylabel='tip'>

# %%
#Give Individual Colors to Hue
my_pal = {"Yes": "g", "No": "b"}
sns.set_style(style="ticks")

sns.boxplot(x="tip",y="day",hue="smoker",data=tip,palette=my_pal,dodge=True)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='day'>

# %%
import numpy as np
import pandas as pd
import seaborn as sns

titanic_data=sns.load_dataset("titanic")
titanic_data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.boxplot(x="survived",y="age",data=titanic_data,showmeans=True)
# Out:
# <AxesSubplot:xlabel='survived', ylabel='age'>

# %%
sns.boxplot(x="survived",y="age",data=titanic_data,showmeans=True,meanprops={"marker":"*","markersize":12,"markeredgecolor":"red"})
# Out:
# <AxesSubplot:xlabel='survived', ylabel='age'>

# %%
sns.boxplot(x="survived",y="age",data=titanic_data,showmeans=True,meanprops={"marker":"+","markersize":12,"markeredgecolor":"red"})
# Out:
# <AxesSubplot:xlabel='survived', ylabel='age'>

# %%
sns.boxplot(x="survived",y="age",data=titanic_data,showmeans=True,meanprops={"marker":"^","markersize":12,"markeredgecolor":"red"})
# Out:
# <AxesSubplot:xlabel='survived', ylabel='age'>

# %%
sns.boxplot(x="survived",y="age",data=titanic_data,showmeans=True,meanprops={"marker":"^","markersize":12,"markeredgecolor":"red"})
plt.xlabel("How many survived Man Or Women",size=20,weight="bold"),
plt.ylabel("How Much Of Age",size=20,weight="bold"),
plt.title("Box Plot Of Live Or Dead Persons",size=20,weight="bold")

plt.show()

# %%
tips = sns.load_dataset("tips")
sns.FacetGrid(tips)

# %%
sns.FacetGrid(tips, col="time", row="sex")

# %%
g = sns.FacetGrid(tips, col="time",  row="sex")
g.map(sns.scatterplot, "total_bill", "tip")

# %%
g = sns.FacetGrid(tips, col="time",  row="sex")
g.map_dataframe(sns.histplot, x="total_bill")

# %%
g = sns.FacetGrid(tips, col="time", row="sex")
g.map_dataframe(sns.histplot, x="total_bill", binwidth=2, binrange=(0, 60))

# %%
g = sns.FacetGrid(tips, col="time", hue="sex")
g.map_dataframe(sns.scatterplot, x="total_bill", y="tip")
g.add_legend()

# %%
g = sns.FacetGrid(tips, col="time")
g.map_dataframe(sns.scatterplot, x="total_bill", y="tip", hue="sex")
g.add_legend()

# %%
g = sns.FacetGrid(tips, col="day", height=3.5, aspect=.65)
g
g.map(sns.histplot, "total_bill")

# %%
g = sns.FacetGrid(tips, col="size", height=2.5, col_wrap=3)
g.map(sns.histplot, "total_bill")

# %%
g = sns.FacetGrid(tips, col="time", margin_titles=True)
g.map_dataframe(sns.scatterplot, x="total_bill", y="tip")
g.refline(y=tips["tip"].median())

# %%
import matplotlib.pyplot as plt
def annotate(data, **kws):
    n = len(data)
    ax = plt.gca()
    ax.text(.1, .6, f"N = {n}", transform=ax.transAxes)

g = sns.FacetGrid(tips, col="time")
g.map_dataframe(sns.scatterplot, x="total_bill", y="tip")
g.map_dataframe(annotate)

# %%
g = sns.FacetGrid(tips, col="sex", row="time", margin_titles=True)
g.map_dataframe(sns.scatterplot, x="total_bill", y="tip")
g.set_axis_labels("Total bill ($)", "Tip ($)")
g.set_titles(col_template="{col_name} patrons", row_template="{row_name}")
g.set(xlim=(0, 60), ylim=(0, 12), xticks=[10, 30, 50], yticks=[2, 6, 10])
g.tight_layout()
g.savefig("facet_plot.png")

# %%
g = sns.FacetGrid(tips, col="sex", row="time", margin_titles=True, despine=False)
g.map_dataframe(sns.scatterplot, x="total_bill", y="tip")
g.figure.subplots_adjust(wspace=0, hspace=0)
for (row_val, col_val), ax in g.axes_dict.items():
    if row_val == "Lunch" and col_val == "Female":
        ax.set_facecolor(".95")
    else:
        ax.set_facecolor((0, 0, 0, 0))
